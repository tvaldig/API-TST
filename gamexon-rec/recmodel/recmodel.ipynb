# %%
import os
import zipfile
import json

# library for data processing
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# library to make the recommendation system model
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity

# library for evaluate the machine learning model
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

# %%
data = pd.read_csv("games_cleaned.csv")
data
# Out:
#        id                                            title     genre  \
# 0       1                        Dead or Alive: Dimensions  Fighting
# 1       2                            Yaiba: Ninja Gaiden Z    Action
# 2       3                          Dynasty Warriors Gundam    Action
# 3       4                         Kengo: Master of Bushido  Fighting
# 4       5                                       Watch Dogs    Action
# ..    ...                                              ...       ...
# 995   996                                Motocross Mania 3    Racing
# 996   997                                     Rocky Balboa    Sports
# 997   998  Lemony Snicket's A Series of Unfortunate Events  Platform
# 998   999                  The Settlers: Rise of an Empire  Strategy
# 999  1000                           The Beatles: Rock Band      Misc
#
#      release_year  popularity                 developer             publisher  \
# 0            2011         8.2                Team Ninja        Ubisoft Annecy
# 1            2014         4.5  Spark Unlimited, comcept            Tecmo Koei
# 2            2007         6.8         Koei, Omega Force    Namco Bandai Games
# 3            2000         8.4              Light Weight               Ubisoft
# 4            2014         6.4           Ubisoft Romania               Ubisoft
# ..            ...         ...                       ...                   ...
# 995          2005         3.6            Deibus Studios  Take-Two Interactive
# 996          2007         6.6                   Ubisoft               Ubisoft
# 997          2004         8.0          Griptonite Games            Activision
# 998          2007         7.7                 Blue Byte               Ubisoft
# 999          2009         8.7    Harmonix Music Systems             MTV Games
#
#      price_per_day rating
# 0             8654      T
# 1             6113      M
# 2             9033      T
# 3             5044      M
# 4             8578      M
# ..             ...    ...
# 995           5103      T
# 996           8502      T
# 997           6760      E
# 998           6903   E10+
# 999           6476      T
#
# [1000 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   title          1000 non-null   object
#  2   genre          1000 non-null   object
#  3   release_year   1000 non-null   int64
#  4   popularity     1000 non-null   float64
#  5   developer      1000 non-null   object
#  6   publisher      1000 non-null   object
#  7   price_per_day  1000 non-null   int64
#  8   rating         1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
data.isnull().sum()
# Out:
# id               0
# title            0
# genre            0
# release_year     0
# popularity       0
# developer        0
# publisher        0
# price_per_day    0
# rating           0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# id               0
# title            0
# genre            0
# release_year     0
# popularity       0
# developer        0
# publisher        0
# price_per_day    0
# rating           0
# dtype: int64

# %%
data = data.reset_index(drop=True)
data
# Out:
#        id                                            title     genre  \
# 0       1                        Dead or Alive: Dimensions  Fighting
# 1       2                            Yaiba: Ninja Gaiden Z    Action
# 2       3                          Dynasty Warriors Gundam    Action
# 3       4                         Kengo: Master of Bushido  Fighting
# 4       5                                       Watch Dogs    Action
# ..    ...                                              ...       ...
# 995   996                                Motocross Mania 3    Racing
# 996   997                                     Rocky Balboa    Sports
# 997   998  Lemony Snicket's A Series of Unfortunate Events  Platform
# 998   999                  The Settlers: Rise of an Empire  Strategy
# 999  1000                           The Beatles: Rock Band      Misc
#
#      release_year  popularity                 developer             publisher  \
# 0            2011         8.2                Team Ninja        Ubisoft Annecy
# 1            2014         4.5  Spark Unlimited, comcept            Tecmo Koei
# 2            2007         6.8         Koei, Omega Force    Namco Bandai Games
# 3            2000         8.4              Light Weight               Ubisoft
# 4            2014         6.4           Ubisoft Romania               Ubisoft
# ..            ...         ...                       ...                   ...
# 995          2005         3.6            Deibus Studios  Take-Two Interactive
# 996          2007         6.6                   Ubisoft               Ubisoft
# 997          2004         8.0          Griptonite Games            Activision
# 998          2007         7.7                 Blue Byte               Ubisoft
# 999          2009         8.7    Harmonix Music Systems             MTV Games
#
#      price_per_day rating
# 0             8654      T
# 1             6113      M
# 2             9033      T
# 3             5044      M
# 4             8578      M
# ..             ...    ...
# 995           5103      T
# 996           8502      T
# 997           6760      E
# 998           6903   E10+
# 999           6476      T
#
# [1000 rows x 9 columns]

# %%
# save game names on new dataframe
df_game_name = pd.DataFrame({'Game': data['title']}).reset_index(drop=True)
df_game_name.head()
# Out:
#                         Game
# 0  Dead or Alive: Dimensions
# 1      Yaiba: Ninja Gaiden Z
# 2    Dynasty Warriors Gundam
# 3   Kengo: Master of Bushido
# 4                 Watch Dogs

# %%
# use name column as index
data.set_index('title', inplace=True)
data.head()
# Out:
#                            id     genre  release_year  popularity  \
# title
# Dead or Alive: Dimensions   1  Fighting          2011         8.2
# Yaiba: Ninja Gaiden Z       2    Action          2014         4.5
# Dynasty Warriors Gundam     3    Action          2007         6.8
# Kengo: Master of Bushido    4  Fighting          2000         8.4
# Watch Dogs                  5    Action          2014         6.4
#
#                                           developer           publisher  \
# title
# Dead or Alive: Dimensions                Team Ninja      Ubisoft Annecy
# Yaiba: Ninja Gaiden Z      Spark Unlimited, comcept          Tecmo Koei
# Dynasty Warriors Gundam           Koei, Omega Force  Namco Bandai Games
# Kengo: Master of Bushido               Light Weight             Ubisoft
# Watch Dogs                          Ubisoft Romania             Ubisoft
#
#                            price_per_day rating
# title
# Dead or Alive: Dimensions           8654      T
# Yaiba: Ninja Gaiden Z               6113      M
# Dynasty Warriors Gundam             9033      T
# Kengo: Master of Bushido            5044      M
# Watch Dogs                          8578      M

# %%
# select all columns with datatype object
column_object = data.dtypes[data.dtypes == 'object'].keys()
column_object

one_hot_label = pd.get_dummies(data[column_object]).astype(int)
one_hot_label.head(3)
# Out:
#                            genre_Action  genre_Adventure  genre_Fighting  \
# title
# Dead or Alive: Dimensions             0                0               1
# Yaiba: Ninja Gaiden Z                 1                0               0
# Dynasty Warriors Gundam               1                0               0
#
#                            genre_Misc  genre_Platform  genre_Puzzle  \
# title
# Dead or Alive: Dimensions           0               0             0
# Yaiba: Ninja Gaiden Z               0               0             0
# Dynasty Warriors Gundam             0               0             0
#
#                            genre_Racing  genre_Role-Playing  genre_Shooter  \
# title
# Dead or Alive: Dimensions             0                   0              0
# Yaiba: Ninja Gaiden Z                 0                   0              0
# Dynasty Warriors Gundam               0                   0              0
#
#                            genre_Simulation  ...  publisher_Vivendi Games  \
# title                                        ...
# Dead or Alive: Dimensions                 0  ...                        0
# Yaiba: Ninja Gaiden Z                     0  ...                        0
# Dynasty Warriors Gundam                   0  ...                        0
#
#                            publisher_Warner Bros. Interactive Entertainment  \
# title
# Dead or Alive: Dimensions                                                 0
# Yaiba: Ninja Gaiden Z                                                     0
# Dynasty Warriors Gundam                                                   0
#
#                            publisher_White Park Bay Software  \
# title
# Dead or Alive: Dimensions                                  0
# Yaiba: Ninja Gaiden Z                                      0
# Dynasty Warriors Gundam                                    0
#
#                            publisher_Zoo Digital Publishing  \
# title
# Dead or Alive: Dimensions                                 0
# Yaiba: Ninja Gaiden Z                                     0
# Dynasty Warriors Gundam                                   0
#
#                            publisher_Zoo Games  publisher_id Software  \
# title
# Dead or Alive: Dimensions                    0                      0
# Yaiba: Ninja Gaiden Z                        0                      0
# Dynasty Warriors Gundam                      0                      0
#
#                            rating_E  rating_E10+  rating_M  rating_T
# title
# Dead or Alive: Dimensions         0            0         0         1
# Yaiba: Ninja Gaiden Z             0            0         1         0
# Dynasty Warriors Gundam           0            0         0         1
#
# [3 rows x 626 columns]

# %%
# delete column with data type object
data.drop(column_object,axis=1,inplace=True)
data.head()
# Out:
#                            id  release_year  popularity  price_per_day
# title
# Dead or Alive: Dimensions   1          2011         8.2           8654
# Yaiba: Ninja Gaiden Z       2          2014         4.5           6113
# Dynasty Warriors Gundam     3          2007         6.8           9033
# Kengo: Master of Bushido    4          2000         8.4           5044
# Watch Dogs                  5          2014         6.4           8578

# %%
# unify one-hot encoding data with whole data
data = pd.concat([data,one_hot_label],axis=1)
data.head()
# Out:
#                            id  release_year  popularity  price_per_day  \
# title
# Dead or Alive: Dimensions   1          2011         8.2           8654
# Yaiba: Ninja Gaiden Z       2          2014         4.5           6113
# Dynasty Warriors Gundam     3          2007         6.8           9033
# Kengo: Master of Bushido    4          2000         8.4           5044
# Watch Dogs                  5          2014         6.4           8578
#
#                            genre_Action  genre_Adventure  genre_Fighting  \
# title
# Dead or Alive: Dimensions             0                0               1
# Yaiba: Ninja Gaiden Z                 1                0               0
# Dynasty Warriors Gundam               1                0               0
# Kengo: Master of Bushido              0                0               1
# Watch Dogs                            1                0               0
#
#                            genre_Misc  genre_Platform  genre_Puzzle  ...  \
# title                                                                ...
# Dead or Alive: Dimensions           0               0             0  ...
# Yaiba: Ninja Gaiden Z               0               0             0  ...
# Dynasty Warriors Gundam             0               0             0  ...
# Kengo: Master of Bushido            0               0             0  ...
# Watch Dogs                          0               0             0  ...
#
#                            publisher_Vivendi Games  \
# title
# Dead or Alive: Dimensions                        0
# Yaiba: Ninja Gaiden Z                            0
# Dynasty Warriors Gundam                          0
# Kengo: Master of Bushido                         0
# Watch Dogs                                       0
#
#                            publisher_Warner Bros. Interactive Entertainment  \
# title
# Dead or Alive: Dimensions                                                 0
# Yaiba: Ninja Gaiden Z                                                     0
# Dynasty Warriors Gundam                                                   0
# Kengo: Master of Bushido                                                  0
# Watch Dogs                                                                0
#
#                            publisher_White Park Bay Software  \
# title
# Dead or Alive: Dimensions                                  0
# Yaiba: Ninja Gaiden Z                                      0
# Dynasty Warriors Gundam                                    0
# Kengo: Master of Bushido                                   0
# Watch Dogs                                                 0
#
#                            publisher_Zoo Digital Publishing  \
# title
# Dead or Alive: Dimensions                                 0
# Yaiba: Ninja Gaiden Z                                     0
# Dynasty Warriors Gundam                                   0
# Kengo: Master of Bushido                                  0
# Watch Dogs                                                0
#
#                            publisher_Zoo Games  publisher_id Software  \
# title
# Dead or Alive: Dimensions                    0                      0
# Yaiba: Ninja Gaiden Z                        0                      0
# Dynasty Warriors Gundam                      0                      0
# Kengo: Master of Bushido                     0                      0
# Watch Dogs                                   0                      0
#
#                            rating_E  rating_E10+  rating_M  rating_T
# title
# Dead or Alive: Dimensions         0            0         0         1
# Yaiba: Ninja Gaiden Z             0            0         1         0
# Dynasty Warriors Gundam           0            0         0         1
# Kengo: Master of Bushido          0            0         1         0
# Watch Dogs                        0            0         1         0
#
# [5 rows x 630 columns]

# %%
column_numeric = list(data.dtypes[data.dtypes == 'float64'].keys())
column_numeric

scaler = MinMaxScaler()
scaled = scaler.fit_transform(data[column_numeric])
i=0
for column in column_numeric:
    data[column] = scaled[:,i]
    i += 1
data.head()
# Out:
#                            id  release_year  popularity  price_per_day  \
# title
# Dead or Alive: Dimensions   1          2011    0.844444           8654
# Yaiba: Ninja Gaiden Z       2          2014    0.433333           6113
# Dynasty Warriors Gundam     3          2007    0.688889           9033
# Kengo: Master of Bushido    4          2000    0.866667           5044
# Watch Dogs                  5          2014    0.644444           8578
#
#                            genre_Action  genre_Adventure  genre_Fighting  \
# title
# Dead or Alive: Dimensions             0                0               1
# Yaiba: Ninja Gaiden Z                 1                0               0
# Dynasty Warriors Gundam               1                0               0
# Kengo: Master of Bushido              0                0               1
# Watch Dogs                            1                0               0
#
#                            genre_Misc  genre_Platform  genre_Puzzle  ...  \
# title                                                                ...
# Dead or Alive: Dimensions           0               0             0  ...
# Yaiba: Ninja Gaiden Z               0               0             0  ...
# Dynasty Warriors Gundam             0               0             0  ...
# Kengo: Master of Bushido            0               0             0  ...
# Watch Dogs                          0               0             0  ...
#
#                            publisher_Vivendi Games  \
# title
# Dead or Alive: Dimensions                        0
# Yaiba: Ninja Gaiden Z                            0
# Dynasty Warriors Gundam                          0
# Kengo: Master of Bushido                         0
# Watch Dogs                                       0
#
#                            publisher_Warner Bros. Interactive Entertainment  \
# title
# Dead or Alive: Dimensions                                                 0
# Yaiba: Ninja Gaiden Z                                                     0
# Dynasty Warriors Gundam                                                   0
# Kengo: Master of Bushido                                                  0
# Watch Dogs                                                                0
#
#                            publisher_White Park Bay Software  \
# title
# Dead or Alive: Dimensions                                  0
# Yaiba: Ninja Gaiden Z                                      0
# Dynasty Warriors Gundam                                    0
# Kengo: Master of Bushido                                   0
# Watch Dogs                                                 0
#
#                            publisher_Zoo Digital Publishing  \
# title
# Dead or Alive: Dimensions                                 0
# Yaiba: Ninja Gaiden Z                                     0
# Dynasty Warriors Gundam                                   0
# Kengo: Master of Bushido                                  0
# Watch Dogs                                                0
#
#                            publisher_Zoo Games  publisher_id Software  \
# title
# Dead or Alive: Dimensions                    0                      0
# Yaiba: Ninja Gaiden Z                        0                      0
# Dynasty Warriors Gundam                      0                      0
# Kengo: Master of Bushido                     0                      0
# Watch Dogs                                   0                      0
#
#                            rating_E  rating_E10+  rating_M  rating_T
# title
# Dead or Alive: Dimensions         0            0         0         1
# Yaiba: Ninja Gaiden Z             0            0         1         0
# Dynasty Warriors Gundam           0            0         0         1
# Kengo: Master of Bushido          0            0         1         0
# Watch Dogs                        0            0         1         0
#
# [5 rows x 630 columns]

# %%
data.to_csv("games_encoded.csv")

# %%
model = NearestNeighbors(metric='euclidean')

# Fit model to the data
model.fit(data)
# Out:
# NearestNeighbors(metric='euclidean')

# %%
# function to get the game recommendation
def GameRecommend(gamename:str, recommended_games:int=4):
  print(f'If user like playing Game: \n{gamename[0]}\n5 Game that the user might like to play:')
  distances, neighbors = model.kneighbors(data.loc[gamename],n_neighbors=recommended_games)
  similar_game = []
  for gamename in df_game_name.loc[neighbors[0][:]].values:
    similar_game.append(gamename[0])
  similar_distance = []
  for distance in distances[0]:
    similar_distance.append(f"{round(100-distance, 2)}%")
  return pd.DataFrame(data = {"Game" : similar_game[1:], "Similarity" : similar_distance[1:]})

# %%
GameRecommend(df_game_name.loc[110])
# Out:
# If user like playing Game:
# The Evil Within
# 5 Game that the user might like to play:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2152\4175884598.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f'If user like playing Game: \n{gamename[0]}\n5 Game that the user might like to play:')
#                          Game Similarity
# 0  Hello Kitty: Roller Rescue     56.78%
# 1                  The Hobbit     55.34%
# 2              FIFA Soccer 10     54.69%
